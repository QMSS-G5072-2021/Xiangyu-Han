# %%
# !which python
# Out:
# /Users/humphreyhan/Library/Caches/pypoetry/virtualenvs/mds-G2ZMO4Sf-py3.9/bin/python

# %%
# !pip install -i https://test.pypi.org/simple/ nyc_crash_api --upgrade
# Out:
# Looking in indexes: https://test.pypi.org/simple/
# ...
#      |████████████████████████████████| 1.5 MB 4.1 MB/s eta 0:00:01
# ...
#   Attempting uninstall: nyc-crash-api
#     Found existing installation: nyc-crash-api 0.12.0
#     Uninstalling nyc-crash-api-0.12.0:
#       Successfully uninstalled nyc-crash-api-0.12.0
# ...

# %%
from nyc_crash_api import nyc_crash_api

# %%
# !poetry run pytest
# Out:
# ============================= test session starts ==============================
# platform darwin -- Python 3.9.0, pytest-5.4.3, py-1.10.0, pluggy-0.13.1
# rootdir: /Users/humphreyhan/Documents/GitHub/Xiangyu_Han/Final_Project
# plugins: mock-3.6.1, Faker-4.18.0
# collected 4 items
#
# nyc_crash_api/tests/test_1.py ....                                       [100%]
#
# ============================== 4 passed in 2.83s ===============================

# %% [markdown]
# ### Option A: Functional / API Project (recommended)
#
# This type of project will not focus on acquiring the data per se, but rather the methods to acquire data and the functions associated with it.
#
# This project will entail writing multiple functions for an API that currently has no Python package associated with it and packaging it into an API client Python package (with the potential for public release).
#
# ##### Presentation
# For the API project, the evaluation will be based on technical difficulties involved, the breadth of skills displayed, and the variety of functions and options included for a user of the API.
#
# A significant part of the package, beyond the documented code and functions themselves, is the use of vignettes. Using one or more Jupyter notebooks, you should aim to show all functionalities of the package to a user of your package.
#
# ##### Output
# The output for evaluation will be an API client wrapped in a Python package. The focus here lies on the quality, usability, and documentation of the functions provided in the package.

# %%
import os
from dotenv import load_dotenv

# %%
load_dotenv(dotenv_path = '/Users/humphreyhan/Documents/GitHub/Xiangyu_Han/Final_Project/crash_env') 
app_token = os.getenv('CRASH_TOKEN')
end_point = 'https://data.cityofnewyork.us/resource/h9gi-nx95.json'

# %% [markdown]
# ### geo

# %%
nyc_crash_api.get_borough_crashes(app_token,'BRONX','2019-07-04T00:00:00','2019-07-04T00:00:00')
# Out:
#                  crash_date crash_time borough zip_code  \
# 0   2019-07-04T00:00:00.000      11:25   BRONX    10467
# 1   2019-07-04T00:00:00.000      22:00   BRONX    10453
# 2   2019-07-04T00:00:00.000      23:30   BRONX    10472
# 3   2019-07-04T00:00:00.000      23:05   BRONX    10462
# 4   2019-07-04T00:00:00.000      20:46   BRONX    10468
# 5   2019-07-04T00:00:00.000       9:58   BRONX    10473
# 6   2019-07-04T00:00:00.000      23:00   BRONX    10466
# 7   2019-07-04T00:00:00.000       0:54   BRONX    10454
# 8   2019-07-04T00:00:00.000      18:11   BRONX    10461
# 9   2019-07-04T00:00:00.000       8:45   BRONX    10460
# 10  2019-07-04T00:00:00.000      23:00   BRONX    10452
# 11  2019-07-04T00:00:00.000      15:27   BRONX    10456
# 12  2019-07-04T00:00:00.000       1:30   BRONX    10457
# 13  2019-07-04T00:00:00.000      20:53   BRONX    10454
# 14  2019-07-04T00:00:00.000      13:53   BRONX    10456
# 15  2019-07-04T00:00:00.000      18:28   BRONX    10465
# ...

# %%
nyc_crash_api.get_zipcode_crashes(app_token,'10025','2019-07-04T00:00:00','2019-07-05T00:00:00')
# Out:
#                 crash_date crash_time    borough zip_code    latitude  \
# 0  2019-07-05T00:00:00.000      19:40  MANHATTAN    10025  40.8015630
#
#      longitude                         cross_street_name  \
# 0  -73.9623700  125       WEST 109 STREET
#
#   number_of_persons_injured number_of_persons_killed  \
# 0                         0                        0
#
#   number_of_pedestrians_injured  ... number_of_cyclist_killed  \
# 0                             0  ...                        0
#
#   number_of_motorist_injured number_of_motorist_killed  \
# 0                          0                         0
#
#   contributing_factor_vehicle_1 contributing_factor_vehicle_2 collision_id  \
# 0                   Unspecified                   Unspecified      4165564
#
#   vehicle_type_code1                   vehicle_type_code2 location.latitude  \
# 0              Sedan  Station Wagon/Sport Utility Vehicle         40.801563
#
#   location.longitude
# 0          -73.96237
#
# ...

# %%
nyc_crash_api.get_crashes_count_by_boroughs(app_token,'2019-07-04T00:00:00','2019-07-06T00:00:00')
# Out:
#          borough number_of_crashes
# 0       BROOKLYN               329
# 1         QUEENS               299
# 2          BRONX               158
# 3      MANHATTAN               129
# 4  STATEN ISLAND                20

# %%
nyc_crash_api.get_heatmap(app_token,'2019-07-04T00:00:00','2019-07-06T00:00:00')
# Out:
# <AxesSubplot:>

# %% [markdown]
# ### time/date:
# trend (injured, killed, crashes)

# %%
nyc_crash_api.get_time_cycle(app_token,'2020-06-06T00:00:00','2020-07-06T00:00:00','all')
# Out:
#     crash_hour  number_of_persons_injured  number_of_persons_killed  \
# 0            0                        179                         4
# 1            1                        103                         2
# 12           2                        106                         0
# 17           3                         63                         1
# 18           4                         47                         2
# 19           5                         56                         0
# 20           6                         63                         0
# 21           7                         87                         0
# 22           8                        115                         1
# 23           9                        116                         0
# 2           10                        122                         1
# 3           11                        151                         0
# 4           12                        188                         1
# ...

# %%
nyc_crash_api.get_contributing_factors(app_token,'2019-07-06T00:00:00','2020-07-06T00:00:00','BROOKLYN')
# Out:
#                                                     COUNT
# Unspecified                                         37580
# Driver Inattention/Distraction                       9743
# Failure to Yield Right-of-Way                        2735
# Following Too Closely                                2104
# Backing Unsafely                                     1839
# Passing Too Closely                                  1835
# Passing or Lane Usage Improper                       1573
# Other Vehicular                                      1380
# Turning Improperly                                    770
# Traffic Control Disregarded                           750
# Driver Inexperience                                   634
# Unsafe Speed                                          612
# Unsafe Lane Changing                                  535
# Alcohol Involvement                                   402
# View Obstructed/Limited                               361
# ...

# %%
nyc_crash_api.get_vehicle_type(app_token,'2019-07-06T00:00:00','2020-07-06T00:00:00','BRONX')
# Out:
#                                      COUNT
# Sedan                                14088
# Station Wagon/Sport Utility Vehicle  10921
# Taxi                                  1126
# Pick-up Truck                          854
# Box Truck                              652
# ...                                    ...
# E-scooter                                1
# Unk                                      1
# Road Sweep                               1
# ENGIN                                    1
# TL                                       1
#
# [180 rows x 1 columns]
