# %%
# %load_ext sql
# Out:
# The sql extension is already loaded. To reload it, use:
#   %reload_ext sql

# %%
# %sql mysql+pymysql://student:mds-is-fun@witchcraft.csbmzoea3lu9.us-east-1.rds.amazonaws.com/witchcraft

# %% [markdown]
# ### 1. Getting to know the data

# %% [markdown]
# ##### a) Show a list of the tables included in the database.

# %%
# %sql SHOW TABLES
# Out:
#  * mysql+pymysql://student:***@witchcraft.csbmzoea3lu9.us-east-1.rds.amazonaws.com/witchcraft
# 37 rows affected.
# [('accused',),
#  ('accused_family',),
#  ('appeal',),
#  ('calendarcustom',),
#  ('case_person',),
#  ('commission',),
#  ('complaint',),
#  ('confession',),
#  ('counterstrategy',),
#  ('demonicpact',),
#  ('denunciation',),
#  ('devilappearance',),
#  ('elf_fairyelements',),
#  ('imprisonment',),
#  ('linkedtrial',),
#  ('malice',),
#  ('mentionedaswitch',),
#  ('movestohla',),
#  ('musicalinstrument',),
#  ('ordeal',),
#  ('othercharges',),
#  ('othernamedwitch',),
#  ('person',),
#  ('prevcommission',),
#  ('propertydamage',),
#  ('ref_parish',),
#  ('reference',),
#  ('religiousmotif',),
#  ('ritualobject',),
#  ('shapechanging',),
#  ('source',),
#  ('torture',),
#  ('trial',),
#  ('trial_person',),
#  ('weathermodification',),
#  ('whitemagic',),
#  ('witchesmeetingplace',)]

# %% [markdown]
# ##### b) Display the column names for the table accused.

# %%
# %%sql
# DESCRIBE accused
# Out:
#  * mysql+pymysql://student:***@witchcraft.csbmzoea3lu9.us-east-1.rds.amazonaws.com/witchcraft
# 31 rows affected.
# [('accusedref', 'varchar(10)', 'YES', '', None, ''),
#  ('accusedsystemid', 'varchar(3)', 'YES', '', None, ''),
#  ('accusedid', 'double', 'YES', '', None, ''),
#  ('firstname', 'varchar(36)', 'YES', '', None, ''),
#  ('lastname', 'varchar(25)', 'YES', '', None, ''),
#  ('m_firstname', 'varchar(29)', 'YES', '', None, ''),
#  ('m_surname', 'varchar(21)', 'YES', '', None, ''),
#  ('alias', 'varchar(26)', 'YES', '', None, ''),
#  ('patronymic', 'varchar(14)', 'YES', '', None, ''),
#  ('destitle', 'varchar(28)', 'YES', '', None, ''),
#  ('sex', 'varchar(6)', 'YES', '', None, ''),
#  ('age', 'double', 'YES', '', None, ''),
#  ('age_estcareer', 'tinyint', 'YES', '', None, ''),
#  ('age_estchild', 'tinyint', 'YES', '', None, ''),
#  ('res_settlement', 'varchar(22)', 'YES', '', None, ''),
#  ('res_parish', 'varchar(10)', 'YES', '', None, ''),
#  ('res_presbytery', 'varchar(17)', 'YES', '', None, ''),
#  ('res_county', 'varchar(13)', 'YES', '', None, ''),
#  ('res_burgh', 'varchar(13)', 'YES', '', None, ''),
#  ('res_ngr_letters', 'varchar(2)', 'YES', '', None, ''),
#  ('res_ngr_easting', 'double', 'YES', '', None, ''),
#  ('res_ngr_northing', 'double', 'YES', '', None, ''),
#  ('ethnic_origin', 'varchar(7)', 'YES', '', None, ''),
#  ('maritalstatus', 'varchar(15)', 'YES', '', None, ''),
#  ('socioecstatus', 'varchar(15)', 'YES', '', None, ''),
#  ('occupation', 'varchar(14)', 'YES', '', None, ''),
#  ('notes', 'text', 'YES', '', None, ''),
#  ('createdby', 'varchar(3)', 'YES', '', None, ''),
#  ('createdate', 'datetime', 'YES', '', None, ''),
#  ('lastupdatedby', 'varchar(3)', 'YES', '', None, ''),
#  ('lastupdatedon', 'datetime', 'YES', '', None, '')]

# %% [markdown]
# ##### c) How many people are included in the accused table?

# %%
# %%sql
# SELECT COUNT(*)
# FROM accused
# Out:
#  * mysql+pymysql://student:***@witchcraft.csbmzoea3lu9.us-east-1.rds.amazonaws.com/witchcraft
# 1 rows affected.
# [(3219,)]

# %% [markdown]
# ##### d) Display the columns firstname, sex, and age for 5 cases in the accused table.

# %%
# %%sql
# SELECT firstname, sex, age
# FROM accused
# LIMIT 5
# Out:
#  * mysql+pymysql://student:***@witchcraft.csbmzoea3lu9.us-east-1.rds.amazonaws.com/witchcraft
# 5 rows affected.
# [('Mareon', 'Female', None),
#  ('Thom', 'Male', None),
#  ('Christian', 'Female', None),
#  ('Janet', 'Female', None),
#  ('Agnes', 'Female', None)]

# %% [markdown]
# ##### e) Looks like the age is missing for some observations. Count the number of nonmissing values for age in the data.

# %%
# %%sql
# SELECT COUNT(age)
# FROM accused
# Out:
#  * mysql+pymysql://student:***@witchcraft.csbmzoea3lu9.us-east-1.rds.amazonaws.com/witchcraft
# 1 rows affected.
# [(166,)]

# %% [markdown]
# ##### f) Show a list of unique occupations.

# %%
# %%sql
# SELECT DISTINCT occupation
# FROM accused
# Out:
#  * mysql+pymysql://student:***@witchcraft.csbmzoea3lu9.us-east-1.rds.amazonaws.com/witchcraft
# 32 rows affected.
# [(None,),
#  ('Servant',),
#  ('Vagabond',),
#  ('Weaver',),
#  ('Midwife',),
#  ('Tailor',),
#  ('Messenger',),
#  ('Brewster',),
#  ('Smith',),
#  ('Minister',),
#  ('Farmer',),
#  ('Mealmaker',),
#  ('Tasker',),
#  ('Maltman',),
#  ('Miller',),
#  ('Healer',),
#  ('Loadman',),
#  ('Blacksmith',),
#  ('Shop-keeper',),
#  ('Stabler',),
#  ('Nurse',),
#  ('Collier',),
#  ('School teacher',),
#  ('Slaterer',),
#  ('Workman',),
#  ('School Master',),
#  ('Merchant',),
#  ('Fisherman',),
#  ('Henwife',),
#  ('Cook',),
#  ('Sailor',),
#  ('Creelman',)]

# %% [markdown]
# ### 2. Seeing the Devil

# %% [markdown]
# ##### a) List the unique devil_types in the data.

# %%
# %%sql
# SELECT DISTINCT devil_type
# FROM devilappearance
# Out:
#  * mysql+pymysql://student:***@witchcraft.csbmzoea3lu9.us-east-1.rds.amazonaws.com/witchcraft
# 16 rows affected.
# [('Male',),
#  ('Female Fairy',),
#  ('Male Fairy',),
#  ('Animal Devil',),
#  ('Spirit',),
#  ('Ghost',),
#  ('Other Demon',),
#  ('Female',),
#  (None,),
#  ('Fairy',),
#  ('Unspecified Devil',),
#  ('Insect Devil',),
#  ('Baby',),
#  ('Human Devil',),
#  ('Child Devil',),
#  ('Inanimate Object Devil',)]

# %% [markdown]
# ##### b) There is also a little description of the type of the devil sighting in the devil_text column. How many of the sightings mention the word "black" in the description?

# %%
# %%sql
# SELECT COUNT(*)
# FROM devilappearance
# WHERE devil_text LIKE "%black%"
# Out:
#  * mysql+pymysql://student:***@witchcraft.csbmzoea3lu9.us-east-1.rds.amazonaws.com/witchcraft
# 1 rows affected.
# [(121,)]

# %% [markdown]
# ##### c) What proportion of the devils (in devil_type) are male?

# %%
# %%sql
# SELECT ROUND(COUNT(devil_type)/(SELECT COUNT(devil_type) FROM devilappearance)*100,2) AS percent_male
# FROM devilappearance
# WHERE devil_type = 'Male'
# Out:
#  * mysql+pymysql://student:***@witchcraft.csbmzoea3lu9.us-east-1.rds.amazonaws.com/witchcraft
# 1 rows affected.
# [(Decimal('63.45'),)]

# %% [markdown]
# ### 3. The trial

# %% [markdown]
# ##### a) What are the average and maximum numbers of male and female accusers?

# %%
# %%sql
# SELECT AVG(female_accusers), AVG(male_accusers), MAX(female_accusers), MAX(male_accusers)
# FROM trial
# Out:
#  * mysql+pymysql://student:***@witchcraft.csbmzoea3lu9.us-east-1.rds.amazonaws.com/witchcraft
# 1 rows affected.
# [(0.2559226932668329, 0.4181988158304768, 27.0, 48.0)]

# %% [markdown]
# ##### b) Count the number of sentences by sentence type. List them in a table (in descending order), excluding missing values. Rename the column headings to something sensible.

# %%
# %%sql
# SELECT sentence AS SentenceType, COUNT(sentence) AS Number_of_Sentence
# FROM trial
# GROUP BY SentenceType
# ORDER BY Number_of_Sentence DESC
# Out:
#  * mysql+pymysql://student:***@witchcraft.csbmzoea3lu9.us-east-1.rds.amazonaws.com/witchcraft
# 11 rows affected.
# [('Execution', 205),
#  ('Released', 52),
#  ('Banishment', 27),
#  ('Declared Fugitive', 11),
#  ('Excommunicated', 6),
#  ('Put to the horn', 2),
#  ('Hang', 1),
#  ('Branded', 1),
#  ('Prison', 1),
#  ('Public Humiliation', 1),
#  (None, 0)]

# %% [markdown]
# ##### c) Do the number of accusers matter for the verdict? Compare the average number of accusers by the type of verdict. Again make sure the table is sorted and the headings make sense.

# %%
# %%sql
# SELECT verdict, ROUND(AVG(male_accusers+female_accusers),2) AS Number_of_Accusers
# FROM trial
# GROUP BY verdict
# ORDER BY Number_of_Accusers DESC
# Out:
#  * mysql+pymysql://student:***@witchcraft.csbmzoea3lu9.us-east-1.rds.amazonaws.com/witchcraft
# 5 rows affected.
# [('Guilty', 5.8),
#  ('Not Guilty', 4.56),
#  ('Not Proven', 1.0),
#  ('Half Guilty', 0.29),
#  (None, 0.2)]

# %% [markdown]
# ##### 4. Tortured Truth

# %% [markdown]
# ##### a) Left join the trial and confession tables. For what share of trials does the database record confessions? Create a results table with the number of all trials, the number of confessions, and the share of trials with confessions recorded.

# %%
# %%sql
# SELECT *
# FROM trial
# LEFT JOIN confession
# ON trial.trialref = confession.trialref
# WHERE confession.trialref IS NOT NULL
# Out:
#  * mysql+pymysql://student:***@witchcraft.csbmzoea3lu9.us-east-1.rds.amazonaws.com/witchcraft
# 941 rows affected.
# [('T/JO/100', 100.0, 'JO', 'C/JO/2669', 2.0, None, None, None, None, None, None, None, None, 0, None, None, 0, None, None, 0, None, None, 0, None, None, None, None, 0, 'Presbytery notes that none of the accused are subject to the authority of ministers or the presbytery and so cannot attest their depositions. Makghie ... (59 characters truncated) ... an be requested.  Note about re-examining the suspects in order to confirm their depositions. Once this had been done commission was to be requested.', None, None, None, None, 0.0, 0.0, 0, 0, None, None, 0, None, None, 0, None, 0, 0, 'No trial details.', 0, None, None, None, None, None, None, None, None, None, None, None, None, None, 'jhm', datetime.datetime(2001, 6, 14, 14, 29, 49), 'LEM', datetime.datetime(2002, 11, 4, 10, 7, 5), 'CF/JO/30', 'JO', 30.0, 'T/JO/100', 0, 1, '11/7/1649', datetime.datetime(2049, 7, 11, 0, 0), None, None, 0, 0, 0, None, 'jhm', datetime.datetime(2001, 6, 14, 14, 30, 46), 'jhm', datetime.datetime(2001, 6, 14, 14, 30, 57)),
#  ('T/JO/1000', 1000.0, 'JO', 'C/EGD/1474', 2.0, None, None, None, None, None, None, None, None, 0, None, None, 0, None, None, 0, None, None, 0, None, None, None, None, 0, 'Commission issued after accused had confessed to some aspect of witchcraft but PC urged the commissioners not to use torture and to ensure that the accused are mentally and legally competent to stand trial.', None, None, None, None, 0.0, 0.0, 0, 0, None, None, 0, None, None, 0, None, 0, 0, 'No details', 0, None, None, None, None, None, None, None, None, None, None, None, None, None, 'jhm', datetime.datetime(2001, 10, 11, 16, 24, 3), 'jhm', datetime.datetime(2002, 10, 8, 10, 56, 6), 'CF/LA/611', 'LA', 611.0, 'T/JO/1000', 0, 1, '14/4/1662', datetime.datetime(1962, 4, 14, 0, 0), None, 'Inshoch', 1, 0, 0, None, 'LEM', datetime.datetime(2002, 8, 20, 14, 43, 7), 'LEM', datetime.datetime(2002, 8, 20, 14, 43, 28)),
#  ('T/JO/1001', 1001.0, 'JO', 'C/EGD/1558', 2.0, None, None, None, None, None, None, None, None, 0, None, None, 0, None, None, 0, None, None, 0, None, None, None, None, 0, 'Commission for trial but the accused was to be legally and mentally competent to stand trial.', None, None, None, None, 0.0, 0.0, 0, 0, None, None, 0, None, None, 0, None, 0, 0, None, 0, None, None, None, None, None, None, None, None, None, None, None, None, None, 'jhm', datetime.datetime(2001, 10, 18, 11, 54, 3), 'jhm', datetime.datetime(2001, 10, 18, 11, 55, 28), 'CF/LA/615', 'LA', 615.0, 'T/JO/1001', 0, 1, '27/5/1662', datetime.datetime(1962, 5, 27, 0, 0), None, 'Auldearn', 1, 0, 0, None, 'LEM', datetime.datetime(2002, 8, 22, 10, 33, 44), 'LEM', datetime.datetime(2002, 8, 22, 10, 34, 11)),
#  ('T/JO/1001', 1001.0, 'JO', 'C/EGD/1558', 2.0, None, None, None, None, None, None, None, None, 0, None, None, 0, None, None, 0, None, None, 0, None, None, None, None, 0, 'Commission for trial but the accused was to be legally and mentally competent to stand trial.', None, None, None, None, 0.0, 0.0, 0, 0, None, None, 0, None, None, 0, None, 0, 0, None, 0, None, None, None, None, None, None, None, None, None, None, None, None, None, 'jhm', datetime.datetime(2001, 10, 18, 11, 54, 3), 'jhm', datetime.datetime(2001, 10, 18, 11, 55, 28), 'CF/LA/614', 'LA', 614.0, 'T/JO/1001', 0, 1, '15/5/1662', datetime.datetime(1962, 5, 15, 0, 0), None, 'Auldearn', 1, 0, 0, None, 'LEM', datetime.datetime(2002, 8, 22, 10, 33, 24), 'LEM', datetime.datetime(2002, 8, 22, 10, 33, 44)),
#  ('T/JO/1001', 1001.0, 'JO', 'C/EGD/1558', 2.0, None, None, None, None, None, None, None, None, 0, None, None, 0, None, None, 0, None, None, 0, None, None, None, None, 0, 'Commission for trial but the accused was to be legally and mentally competent to stand trial.', None, None, None, None, 0.0, 0.0, 0, 0, None, None, 0, None, None, 0, None, 0, 0, None, 0, None, None, None, None, None, None, None, None, None, None, None, None, None, 'jhm', datetime.datetime(2001, 10, 18, 11, 54, 3), 'jhm', datetime.datetime(2001, 10, 18, 11, 55, 28), 'CF/LA/613', 'LA', 613.0, 'T/JO/1001', 0, 1, '3/5/1662', datetime.datetime(1962, 5, 3, 0, 0), None, 'Auldearn', 1, 0, 0, None, 'LEM', datetime.datetime(2002, 8, 22, 10, 32, 53), 'LEM', datetime.datetime(2002, 8, 22, 10, 33, 23)),
#  ('T/JO/1001', 1001.0, 'JO', 'C/EGD/1558', 2.0, None, None, None, None, None, None, None, None, 0, None, None, 0, None, None, 0, None, None, 0, None, None, None, None, 0, 'Commission for trial but the accused was to be legally and mentally competent to stand trial.', None, None, None, None, 0.0, 0.0, 0, 0, None, None, 0, None, None, 0, None, 0, 0, None, 0, None, None, None, None, None, None, None, None, None, None, None, None, None, 'jhm', datetime.datetime(2001, 10, 18, 11, 54, 3), 'jhm', datetime.datetime(2001, 10, 18, 11, 55, 28), 'CF/LA/612', 'LA', 612.0, 'T/JO/1001', 0, 1, '13/4/1662', datetime.datetime(1962, 4, 13, 0, 0), None, 'Auldearn', 1, 0, 0, None, 'LEM', datetime.datetime(2002, 8, 20, 17, 3, 46), 'LEM', datetime.datetime(2002, 8, 20, 17, 3, 55)),
#  ('T/JO/1002', 1002.0, 'JO', 'C/EGD/1681', 2.0, None, None, None, None, None, None, None, None, 0, None, None, 0, None, None, 0, None, None, 0, None, None, None, None, 0, 'Commission issued after accused had confessed but PC urged caution about use of torture. The accusedwas  to confess voluntarily and be of legal and mental competency to stand trial.', None, None, None, None, 0.0, 0.0, 0, 0, None, None, 0, None, None, 0, None, 0, 0, 'No details', 0, None, None, None, None, None, None, None, None, None, None, None, None, 'No details', 'jhm', datetime.datetime(2001, 10, 18, 12, 23, 35), 'jhm', datetime.datetime(2002, 10, 21, 16, 11, 47), 'CF/JO/717', 'JO', 717.0, 'T/JO/1002', 0, 1, None, None, None, None, 0, 0, 0, None, 'jhm', datetime.datetime(2002, 10, 21, 16, 11, 58), 'jhm', datetime.datetime(2002, 10, 21, 16, 12)),
#  ('T/JO/1003', 1003.0, 'JO', 'C/EGD/1680', 2.0, None, None, None, None, None, None, None, None, 0, None, None, 0, None, None, 0, None, None, 0, None, None, None, None, 0, 'Commission issued after the accused had confessed.', None, None, None, None, 0.0, 0.0, 0, 0, None, None, 0, None, None, 0, None, 0, 0, 'No details', 0, None, None, None, None, None, None, None, None, None, None, None, None, 'No details', 'jhm', datetime.datetime(2001, 10, 18, 12, 44, 59), 'jhm', datetime.datetime(2001, 10, 18, 12, 46, 17), 'CF/JO/425', 'JO', 425.0, 'T/JO/1003', 0, 1, '7/1662', datetime.datetime(1962, 7, 1, 0, 0), None, None, 0, 0, 0, None, 'jhm', datetime.datetime(2001, 10, 18, 12, 45, 24), 'jhm', datetime.datetime(2001, 10, 18, 12, 45, 29)),
#  ('T/JO/1004', 1004.0, 'JO', 'C/EGD/1682', 2.0, None, None, None, None, None, None, None, None, 0, None, None, 0, None, None, 0, None, None, 0, None, None, None, None, 0, 'Commission issued after the accused had confessed.', None, None, None, None, 0.0, 0.0, 0, 0, None, None, 0, None, None, 0, None, 0, 0, 'No details', 0, None, None, None, None, None, None, None, None, None, None, None, None, 'No details', 'jhm', datetime.datetime(2001, 10, 18, 12, 47, 54), 'jhm', datetime.datetime(2001, 10, 18, 12, 49, 13), 'CF/JO/426', 'JO', 426.0, 'T/JO/1004', 0, 1, '7/1662', datetime.datetime(1962, 7, 1, 0, 0), None, None, 0, 0, 0, None, 'jhm', datetime.datetime(2001, 10, 18, 12, 48, 17), 'jhm', datetime.datetime(2001, 10, 18, 12, 48, 22)),
#  ('T/JO/1005', 1005.0, 'JO', 'C/EGD/1683', 2.0, None, None, None, None, None, None, None, None, 0, None, None, 0, None, None, 0, None, None, 0, None, None, None, None, 0, 'Commission issued after the accused had confessed.', None, None, None, None, 0.0, 0.0, 0, 0, None, None, 0, None, None, 0, None, 0, 0, 'No details', 0, None, None, None, None, None, None, None, None, None, None, None, None, 'No details', 'jhm', datetime.datetime(2001, 10, 18, 12, 50, 55), 'jhm', datetime.datetime(2001, 10, 18, 12, 53, 24), 'CF/JO/427', 'JO', 427.0, 'T/JO/1005', 0, 1, '7/1662', datetime.datetime(1962, 7, 1, 0, 0), None, None, 0, 0, 0, None, 'jhm', datetime.datetime(2001, 10, 18, 12, 51, 25), 'jhm', datetime.datetime(2001, 10, 18, 12, 52, 28)),
#  ('T/JO/1006', 1006.0, 'JO', 'C/JO/2902', 2.0, None, None, None, None, None, None, None, None, 0, None, None, 0, None, None, 0, None, None, 0, None, None, None, None, 0, 'Commission issued after the accused had confessed.', None, None, None, None, 0.0, 0.0, 0, 0, None, None, 0, None, None, 0, None, 0, 0, 'No details', 0, None, None, None, None, None, None, None, None, None, None, None, None, 'No details', 'jhm', datetime.datetime(2001, 10, 18, 12, 55, 13), 'jhm', datetime.datetime(2001, 10, 18, 12, 55, 53), 'CF/JO/428', 'JO', 428.0, 'T/JO/1006', 0, 1, '7/1662', datetime.datetime(1962, 7, 1, 0, 0), None, None, 0, 0, 0, None, 'jhm', datetime.datetime(2001, 10, 18, 12, 55, 35), 'jhm', datetime.datetime(2001, 10, 18, 12, 55, 39)),
#  ('T/JO/1013', 1013.0, 'JO', 'C/EGD/1691', 2.0, None, None, None, None, None, None, None, None, 0, None, None, 0, None, None, 0, None, None, 0, None, None, None, None, 0, 'Accused recorded as having confessed before commission issued.', None, None, None, None, 0.0, 0.0, 0, 0, None, None, 0, None, None, 0, None, 0, 0, 'No details', 0, None, None, None, None, None, None, None, None, None, None, None, None, 'No details', 'jhm', datetime.datetime(2001, 10, 18, 15, 38, 38), 'jhm', datetime.datetime(2001, 10, 18, 15, 39, 31), 'CF/JO/429', 'JO', 429.0, 'T/JO/1013', 0, 1, '7/1662', datetime.datetime(1962, 7, 1, 0, 0), None, None, 0, 0, 0, None, 'jhm', datetime.datetime(2001, 10, 18, 15, 39, 11), 'jhm', datetime.datetime(2001, 10, 18, 15, 39, 21)),
#  ('T/JO/1014', 1014.0, 'JO', 'C/EGD/1690', 2.0, None, None, None, None, None, None, None, None, 0, None, None, 0, None, None, 0, None, None, 0, None, None, None, None, 0, 'Commission appears to have been issued after the accused confessed.', None, None, None, None, 0.0, 0.0, 0, 0, None, None, 0, None, None, 0, None, 0, 0, 'No details', 0, None, None, None, None, None, None, None, None, None, None, None, None, 'No details', 'jhm', datetime.datetime(2001, 10, 18, 15, 42, 58), 'jhm', datetime.datetime(2001, 10, 18, 15, 48, 41), 'CF/JO/430', 'JO', 430.0, 'T/JO/1014', 0, 1, '7/1662', datetime.datetime(1962, 7, 1, 0, 0), None, None, 0, 0, 0, None, 'jhm', datetime.datetime(2001, 10, 18, 15, 43, 25), 'jhm', datetime.datetime(2001, 10, 18, 15, 43, 29)),
#  ('T/JO/1015', 1015.0, 'JO', 'C/EGD/1694', 2.0, None, None, None, None, None, None, None, None, 0, None, None, 0, None, None, 0, None, None, 0, None, None, None, None, 0, 'Commission issued after the accused had confessed.', None, None, None, None, 0.0, 0.0, 0, 0, None, None, 0, None, None, 0, None, 0, 0, 'No details', 0, None, None, None, None, None, None, None, None, None, None, None, None, 'No details', 'jhm', datetime.datetime(2001, 10, 18, 15, 56, 14), 'jhm', datetime.datetime(2001, 10, 18, 15, 56, 51), 'CF/JO/431', 'JO', 431.0, 'T/JO/1015', 0, 1, '8/1662', datetime.datetime(1962, 8, 1, 0, 0), None, None, 0, 0, 0, None, 'jhm', datetime.datetime(2001, 10, 18, 15, 56, 36), 'jhm', datetime.datetime(2001, 10, 18, 15, 56, 40)),
#  ('T/JO/1016', 1016.0, 'JO', 'C/EGD/1693', 2.0, None, None, None, None, None, None, None, None, 0, None, None, 0, None, None, 0, None, None, 0, None, None, None, None, 0, 'Commission issued after the accused had confessed.', None, None, None, None, 0.0, 0.0, 0, 0, None, None, 0, None, None, 0, None, 0, 0, 'No details', 0, None, None, None, None, None, None, None, None, None, None, None, None, 'No detaisl', 'jhm', datetime.datetime(2001, 10, 18, 15, 59, 12), 'jhm', datetime.datetime(2001, 10, 18, 15, 59, 49), 'CF/JO/432', 'JO', 432.0, 'T/JO/1016', 0, 1, '8/1662', datetime.datetime(1962, 8, 1, 0, 0), None, None, 0, 0, 0, None, 'jhm', datetime.datetime(2001, 10, 18, 15, 59, 31), 'jhm', datetime.datetime(2001, 10, 18, 15, 59, 39)),
#  ('T/JO/102', 102.0, 'JO', 'C/EGD/1316', 2.0, None, None, None, None, None, None, None, None, 0, None, None, 1, None, None, 0, None, None, 0, None, None, None, None, 0, 'Deposition attested and request for commission to try and judge the suspect recorded in presbytery records.', None, None, None, None, 0.0, 0.0, 0, 0, None, None, 0, None, None, 0, None, 0, 0, 'No trial details.', 0, None, None, None, None, None, None, None, None, None, None, None, None, None, 'jhm', datetime.datetime(2001, 6, 14, 14, 42, 58), 'LEM', datetime.datetime(2002, 10, 28, 12, 53, 55), 'CF/JO/31', 'JO', 31.0, 'T/JO/102', 0, 1, '11/7/1649', datetime.datetime(2049, 7, 11, 0, 0), None, 'Haddington', 0, 0, 0, None, 'jhm', datetime.datetime(2001, 6, 14, 14, 43, 48), 'jhm', datetime.datetime(2001, 6, 14, 14, 44, 8)),
#  ('T/JO/1022', 1022.0, 'JO', 'C/EGD/1367', 2.0, None, None, None, None, None, None, None, None, 0, None, None, 0, None, None, 0, None, None, 0, None, None, None, None, 0, None, None, None, None, None, 0.0, 0.0, 0, 0, None, None, 0, None, None, 0, None, 0, 0, 'No details', 0, None, None, None, None, None, None, None, None, None, None, None, None, 'No details', 'jhm', datetime.datetime(2001, 10, 19, 10, 31, 51), 'jhm', datetime.datetime(2001, 10, 19, 10, 32, 26), 'CF/JO/433', 'JO', 433.0, 'T/JO/1022', 0, 1, '28/5/1661', datetime.datetime(1961, 5, 28, 0, 0), None, 'Bolton', 0, 1, 0, None, 'jhm', datetime.datetime(2001, 10, 19, 10, 31, 57), 'jhm', datetime.datetime(2001, 10, 19, 10, 32, 13)),
#  ('T/JO/1023', 1023.0, 'JO', 'C/EGD/1368', 2.0, None, None, None, None, None, None, None, None, 0, None, None, 0, None, None, 0, None, None, 0, None, None, None, None, 0, None, None, None, None, None, 0.0, 0.0, 0, 0, None, None, 0, None, None, 0, None, 0, 0, 'No details', 0, None, None, None, None, None, None, None, None, None, None, None, None, 'No details', 'jhm', datetime.datetime(2001, 10, 19, 10, 54, 12), 'jhm', datetime.datetime(2001, 10, 19, 10, 54, 37), 'CF/JO/434', 'JO', 434.0, 'T/JO/1023', 0, 1, '29/5/1661', datetime.datetime(1961, 5, 29, 0, 0), None, 'Bolton', 0, 1, 0, None, 'jhm', datetime.datetime(2001, 10, 19, 10, 54, 16), 'jhm', datetime.datetime(2001, 10, 19, 10, 54, 27)),
#  ('T/JO/1024', 1024.0, 'JO', 'C/EGD/1375', 2.0, None, None, None, None, None, None, None, None, 0, None, None, 0, None, None, 0, None, None, 0, None, None, None, None, 0, None, None, None, None, None, 0.0, 0.0, 0, 0, None, None, 0, None, None, 0, None, 0, 0, 'No details', 0, None, None, None, None, None, None, None, None, None, None, None, None, 'No details', 'jhm', datetime.datetime(2001, 10, 19, 12, 4, 7), 'jhm', datetime.datetime(2001, 10, 19, 12, 4, 40), 'CF/JO/435', 'JO', 435.0, 'T/JO/1024', 0, 1, '30/5/1661', datetime.datetime(1961, 5, 30, 0, 0), None, 'Bolton', 0, 1, 0, None, 'jhm', datetime.datetime(2001, 10, 19, 12, 4, 14), 'jhm', datetime.datetime(2001, 10, 19, 12, 4, 27)),
#  ('T/JO/1025', 1025.0, 'JO', 'C/EGD/1372', 2.0, None, None, None, None, None, None, None, None, 0, None, None, 0, None, None, 0, None, None, 0, None, None, None, None, 0, None, None, None, None, None, 0.0, 0.0, 0, 0, None, None, 0, None, None, 0, None, 0, 0, 'No details', 0, None, None, None, None, None, None, None, None, None, None, None, None, 'No details', 'jhm', datetime.datetime(2001, 10, 19, 12, 19, 37), 'jhm', datetime.datetime(2001, 10, 19, 12, 20, 2), 'CF/JO/436', 'JO', 436.0, 'T/JO/1025', 0, 1, '29/5/1661', datetime.datetime(1961, 5, 29, 0, 0), None, 'Bolton', 0, 1, 0, None, 'jhm', datetime.datetime(2001, 10, 19, 12, 19, 43), 'jhm', datetime.datetime(2001, 10, 19, 12, 19, 52)),
#  ('T/JO/1026', 1026.0, 'JO', 'C/EGD/1373', 2.0, None, None, None, None, None, None, None, None, 0, None, None, 0, None, None, 0, None, None, 0, None, None, None, None, 0, None, None, None, None, None, 0.0, 0.0, 0, 0, None, None, 0, None, None, 0, None, 0, 0, 'No details', 0, None, None, None, None, None, None, None, None, None, None, None, None, 'No details', 'jhm', datetime.datetime(2001, 10, 19, 12, 37, 42), 'jhm', datetime.datetime(2001, 10, 19, 12, 38, 8), 'CF/JO/437', 'JO', 437.0, 'T/JO/1026', 0, 1, '31/5/1661', datetime.datetime(1961, 5, 31, 0, 0), None, 'Bolton', 0, 1, 0, None, 'jhm', datetime.datetime(2001, 10, 19, 12, 37, 45), 'jhm', datetime.datetime(2001, 10, 19, 12, 37, 56)),
#  ('T/JO/1027', 1027.0, 'JO', 'C/JO/2905', 2.0, None, None, None, None, None, None, None, None, 0, None, None, 0, None, None, 0, None, None, 0, None, None, None, None, 0, None, None, None, None, None, 0.0, 0.0, 0, 0, None, None, 0, None, None, 0, None, 0, 0, 'No details', 0, None, None, None, None, None, None, None, None, None, None, None, None, 'No details', 'jhm', datetime.datetime(2001, 10, 19, 12, 58, 56), 'jhm', datetime.datetime(2001, 10, 19, 12, 59, 22), 'CF/JO/438', 'JO', 438.0, 'T/JO/1027', 0, 1, '2/6/1661', datetime.datetime(1961, 6, 2, 0, 0), None, 'Bolton', 0, 1, 0, None, 'jhm', datetime.datetime(2001, 10, 19, 12, 59), 'jhm', datetime.datetime(2001, 10, 19, 12, 59, 11)),
#  ('T/JO/1028', 1028.0, 'JO', 'C/EGD/1374', 2.0, None, None, None, None, None, None, None, None, 0, None, None, 0, None, None, 0, None, None, 0, None, None, None, None, 0, None, None, None, None, None, 0.0, 0.0, 0, 0, None, None, 0, None, None, 0, None, 0, 0, 'No details', 0, None, None, None, None, None, None, None, None, None, None, None, None, 'No details', 'jhm', datetime.datetime(2001, 10, 19, 13, 7, 25), 'jhm', datetime.datetime(2001, 10, 19, 13, 7, 52), 'CF/JO/439', 'JO', 439.0, 'T/JO/1028', 0, 1, '2/6/1661', datetime.datetime(1961, 6, 2, 0, 0), None, 'Bolton', 0, 1, 0, None, 'jhm', datetime.datetime(2001, 10, 19, 13, 7, 30), 'jhm', datetime.datetime(2001, 10, 19, 13, 7, 40)),
#  ('T/JO/104', 104.0, 'JO', 'C/EGD/1315', 2.0, None, None, None, None, None, None, None, None, 0, None, None, 1, None, None, 0, None, None, 0, None, None, None, None, 0, 'Note in presbytery that suspect imprisoned, depositions attested and commission to be requested.', None, None, None, None, 0.0, 0.0, 0, 0, None, None, 0, None, None, 0, None, 0, 0, 'No trial details.', 0, None, None, None, None, None, None, None, None, None, None, None, None, None, 'jhm', datetime.datetime(2001, 6, 14, 15, 0, 55), 'LEM', datetime.datetime(2002, 10, 28, 12, 53, 39), 'CF/JO/32', 'JO', 32.0, 'T/JO/104', 0, 1, '11/7/1649', datetime.datetime(2049, 7, 11, 0, 0), None, 'Haddington', 0, 0, 0, None, 'jhm', datetime.datetime(2001, 6, 14, 15, 2, 16), 'jhm', datetime.datetime(2001, 6, 14, 15, 2, 28)),
#  ('T/JO/105', 105.0, 'JO', 'C/JO/2670', 2.0, None, None, None, None, None, None, None, None, 0, None, None, 1, None, None, 0, None, None, 0, None, None, None, None, 0, 'Note in presbytery records that suspect imprisoned with 2 others and that commission is to be requested.', None, None, None, None, 0.0, 0.0, 0, 0, None, None, 0, None, None, 0, None, 0, 0, 'No trial details.', 0, None, None, None, None, None, None, None, None, None, None, None, None, None, 'jhm', datetime.datetime(2001, 6, 14, 15, 13, 58), 'jhm', datetime.datetime(2002, 10, 11, 16, 41, 32), 'CF/JO/33', 'JO', 33.0, 'T/JO/105', 0, 1, None, None, None, 'Haddington', 0, 0, 0, None, 'jhm', datetime.datetime(2001, 6, 14, 15, 15, 41), 'jhm', datetime.datetime(2001, 6, 14, 15, 15, 49)),
#  ('T/JO/107', 107.0, 'JO', 'C/EGD/1337', 2.0, None, None, None, None, None, None, None, None, 0, None, None, 1, None, None, 0, None, None, 0, None, None, None, None, 0, 'Presbytery notes that deposition from accused had been attested and therefore commission for trial and judge was to be requested.', None, None, None, None, 0.0, 0.0, 0, 0, None, None, 0, None, None, 0, None, 0, 0, 'No details.', 0, None, None, None, None, None, None, None, None, None, None, None, None, None, 'jhm', datetime.datetime(2001, 6, 15, 9, 21, 39), 'LEM', datetime.datetime(2002, 10, 28, 12, 55, 1), 'CF/JO/36', 'JO', 36.0, 'T/JO/107', 0, 1, '25/7/1649', datetime.datetime(2049, 7, 25, 0, 0), None, 'Haddington', 0, 0, 0, None, 'jhm', datetime.datetime(2001, 6, 15, 9, 23, 36), 'jhm', datetime.datetime(2001, 6, 15, 9, 23, 49)),
#  ('T/JO/1077', 1077.0, 'JO', 'C/EGD/2453', 2.0, None, None, None, None, None, None, None, None, 0, None, None, 1, '29/1/1706', datetime.datetime(2006, 1, 29, 0, 0), 1, '17/6/1706', datetime.datetime(2006, 6, 17, 0, 0), 0, None, None, None, None, 0, "Request for commission recorded as having been sent to Queen's Advocate in Edinburgh, but no record of any reply or commission.The presbytery paid for her keep in prison, later they called in bonds of money due to the accused (£40 Scots) which was used to pay for her imprisonment.", None, None, None, None, 0.0, 0.0, 0, 0, 'Guilty', 'Excommunicated', 0, None, None, 0, None, 0, 1, 'Did not appear for trial as she had escaped. Sentence of excommunication passed.', 0, None, None, None, None, None, None, None, None, None, None, None, None, 'Escaped prison and declared excommunicated.', 'jhm', datetime.datetime(2001, 10, 23, 10, 44, 33), 'jhm', datetime.datetime(2002, 10, 29, 12, 35, 19), 'CF/JO/443', 'JO', 443.0, 'T/JO/1077', 0, 1, '19/3/1706', datetime.datetime(2006, 3, 19, 0, 0), None, 'Wigtown', 0, 1, 0, None, 'jhm', datetime.datetime(2001, 10, 23, 10, 46, 41), 'jhm', datetime.datetime(2001, 10, 23, 10, 47, 10)),
#  ('T/JO/1077', 1077.0, 'JO', 'C/EGD/2453', 2.0, None, None, None, None, None, None, None, None, 0, None, None, 1, '29/1/1706', datetime.datetime(2006, 1, 29, 0, 0), 1, '17/6/1706', datetime.datetime(2006, 6, 17, 0, 0), 0, None, None, None, None, 0, "Request for commission recorded as having been sent to Queen's Advocate in Edinburgh, but no record of any reply or commission.The presbytery paid for her keep in prison, later they called in bonds of money due to the accused (£40 Scots) which was used to pay for her imprisonment.", None, None, None, None, 0.0, 0.0, 0, 0, 'Guilty', 'Excommunicated', 0, None, None, 0, None, 0, 1, 'Did not appear for trial as she had escaped. Sentence of excommunication passed.', 0, None, None, None, None, None, None, None, None, None, None, None, None, 'Escaped prison and declared excommunicated.', 'jhm', datetime.datetime(2001, 10, 23, 10, 44, 33), 'jhm', datetime.datetime(2002, 10, 29, 12, 35, 19), 'CF/JO/442', 'JO', 442.0, 'T/JO/1077', 0, 1, '20/2/1706', datetime.datetime(2006, 2, 20, 0, 0), None, 'Wigtown', 0, 1, 0, None, 'jhm', datetime.datetime(2001, 10, 23, 10, 46, 20), 'jhm', datetime.datetime(2001, 10, 23, 10, 46, 41)),
#  ('T/JO/1077', 1077.0, 'JO', 'C/EGD/2453', 2.0, None, None, None, None, None, None, None, None, 0, None, None, 1, '29/1/1706', datetime.datetime(2006, 1, 29, 0, 0), 1, '17/6/1706', datetime.datetime(2006, 6, 17, 0, 0), 0, None, None, None, None, 0, "Request for commission recorded as having been sent to Queen's Advocate in Edinburgh, but no record of any reply or commission.The presbytery paid for her keep in prison, later they called in bonds of money due to the accused (£40 Scots) which was used to pay for her imprisonment.", None, None, None, None, 0.0, 0.0, 0, 0, 'Guilty', 'Excommunicated', 0, None, None, 0, None, 0, 1, 'Did not appear for trial as she had escaped. Sentence of excommunication passed.', 0, None, None, None, None, None, None, None, None, None, None, None, None, 'Escaped prison and declared excommunicated.', 'jhm', datetime.datetime(2001, 10, 23, 10, 44, 33), 'jhm', datetime.datetime(2002, 10, 29, 12, 35, 19), 'CF/JO/441', 'JO', 441.0, 'T/JO/1077', 0, 1, '19/2/1706', datetime.datetime(2006, 2, 19, 0, 0), None, 'Wigtown', 0, 1, 0, None, 'jhm', datetime.datetime(2001, 10, 23, 10, 46, 1), 'jhm', datetime.datetime(2001, 10, 23, 10, 46, 20)),
#  ('T/JO/1077', 1077.0, 'JO', 'C/EGD/2453', 2.0, None, None, None, None, None, None, None, None, 0, None, None, 1, '29/1/1706', datetime.datetime(2006, 1, 29, 0, 0), 1, '17/6/1706', datetime.datetime(2006, 6, 17, 0, 0), 0, None, None, None, None, 0, "Request for commission recorded as having been sent to Queen's Advocate in Edinburgh, but no record of any reply or commission.The presbytery paid for her keep in prison, later they called in bonds of money due to the accused (£40 Scots) which was used to pay for her imprisonment.", None, None, None, None, 0.0, 0.0, 0, 0, 'Guilty', 'Excommunicated', 0, None, None, 0, None, 0, 1, 'Did not appear for trial as she had escaped. Sentence of excommunication passed.', 0, None, None, None, None, None, None, None, None, None, None, None, None, 'Escaped prison and declared excommunicated.', 'jhm', datetime.datetime(2001, 10, 23, 10, 44, 33), 'jhm', datetime.datetime(2002, 10, 29, 12, 35, 19), 'CF/JO/440', 'JO', 440.0, 'T/JO/1077', 0, 1, '30/1/1706', datetime.datetime(2006, 1, 30, 0, 0), None, 'Wigtown', 0, 1, 0, None, 'jhm', datetime.datetime(2001, 10, 23, 10, 45, 29), 'jhm', datetime.datetime(2001, 10, 23, 10, 46, 1)),
#  ('T/JO/108', 108.0, 'JO', 'C/EGD/1318', 2.0, None, None, None, None, None, None, None, None, 0, None, None, 1, None, None, 0, None, None, 0, None, None, None, None, 0, 'deposition attested and commission for trial and judge requested. 12 others named in list for commission.', None, None, None, None, 0.0, 0.0, 0, 0, None, None, 0, None, None, 0, None, 0, 0, 'No details of trial.', 0, None, None, None, None, None, None, None, None, None, None, None, None, None, 'jhm', datetime.datetime(2001, 6, 15, 9, 38, 27), 'LEM', datetime.datetime(2002, 10, 28, 12, 54, 9), 'CF/JO/37', 'JO', 37.0, 'T/JO/108', 0, 1, '25/7/1649', datetime.datetime(2049, 7, 25, 0, 0), None, 'Haddington', 0, 0, 0, None, 'jhm', datetime.datetime(2001, 6, 15, 9, 40, 15), 'jhm', datetime.datetime(2001, 6, 15, 9, 40, 32)),
#  ('T/JO/109', 109.0, 'JO', 'C/JO/2672', 2.0, None, None, None, None, None, None, None, None, 0, None, None, 1, None, None, 0, None, None, 0, None, None, None, None, 0, 'deposition attested and commission to try and judge to be requested.', None, None, None, None, 0.0, 0.0, 0, 0, None, None, 0, None, None, 0, None, 0, 0, 'No trial details.', 0, None, None, None, None, None, None, None, None, None, None, None, None, None, 'jhm', datetime.datetime(2001, 6, 15, 9, 49, 42), 'jhm', datetime.datetime(2002, 10, 11, 16, 41, 38), 'CF/JO/38', 'JO', 38.0, 'T/JO/109', 0, 1, '25/7/1649', datetime.datetime(2049, 7, 25, 0, 0), None, 'Haddington', 0, 0, 0, None, 'jhm', datetime.datetime(2001, 6, 15, 9, 51, 24), 'jhm', datetime.datetime(2001, 6, 15, 9, 51, 40)),
#  ('T/JO/1109', 1109.0, 'JO', 'C/EGD/2471', 2.0, None, None, None, None, None, None, None, None, 0, None, None, 0, None, None, 0, None, None, 0, None, None, None, None, 0, "Local ministers and lairds (?elders) involved. Reported that the accused confessed  in her local kirk. Investigation went on for some months and seve ... (157 characters truncated) ...  be requested. 20/7/1642 Mr John Currie reported that the council felt the points of the application in 'no wayes demerit death', ?no further action.", None, None, None, None, 0.0, 0.0, 0, 0, None, None, 0, None, None, 0, None, 0, 0, None, 0, None, None, None, None, None, None, None, None, None, None, None, None, None, 'jhm', datetime.datetime(2001, 11, 23, 14, 9), 'jhm', datetime.datetime(2002, 10, 30, 9, 48, 44), 'CF/JO/447', 'JO', 447.0, 'T/JO/1109', 0, 1, '5/1640', datetime.datetime(2040, 5, 1, 0, 0), 'Church', 'Coulter', 0, 0, 0, None, 'jhm', datetime.datetime(2001, 11, 23, 14, 11, 37), 'jhm', datetime.datetime(2001, 11, 23, 14, 12, 28)),
#  ('T/JO/111', 111.0, 'JO', 'C/JO/2673', 2.0, None, None, None, None, None, None, None, None, 0, None, None, 1, None, None, 0, None, None, 0, None, None, None, None, 0, 'deposition attested and commission for trial and judge to be requested.', None, None, None, None, 0.0, 0.0, 0, 0, None, None, 0, None, None, 0, None, 0, 0, 'No details', 0, None, None, None, None, None, None, None, None, None, None, None, None, None, 'jhm', datetime.datetime(2001, 6, 15, 10, 0, 9), 'jhm', datetime.datetime(2002, 10, 11, 16, 41, 56), 'CF/JO/39', 'JO', 39.0, 'T/JO/111', 0, 1, '25/7/1649', datetime.datetime(2049, 7, 25, 0, 0), None, 'Haddington', 0, 0, 0, None, 'jhm', datetime.datetime(2001, 6, 15, 10, 1, 14), 'jhm', datetime.datetime(2001, 6, 15, 10, 1, 24)),
#  ('T/JO/1118', 1118.0, 'JO', 'C/EGD/1818', 2.0, None, None, None, None, None, None, None, None, 0, None, None, 1, '22/11/1649', datetime.datetime(2049, 11, 22, 0, 0), 0, None, None, 1, '18/4/1650', datetime.datetime(1950, 4, 18, 0, 0), None, 'Presbytery', 0, 'Named by Janet Coutts (C/EGD/1817). Investigations made at local level and committee of estates applied to for commisison. Suspects examined by Cathi ... (51 characters truncated) ... to have been non-existent. Hunter at one point confessed to demonic stuff but this appears not to have been enough to convict and case was dismissed.', None, None, None, None, 0.0, 0.0, 0, 0, None, None, 0, None, None, 0, None, 0, 0, None, 0, None, None, None, None, None, None, None, None, None, None, None, None, None, 'jhm', datetime.datetime(2001, 11, 27, 13, 58, 2), 'jhm', datetime.datetime(2002, 10, 22, 13, 2, 17), 'CF/JO/450', 'JO', 450.0, 'T/JO/1118', 0, 1, '10/1/1650', datetime.datetime(1950, 1, 10, 0, 0), None, 'Lanark', 0, 0, 0, None, 'jhm', datetime.datetime(2001, 11, 27, 14, 1, 14), 'jhm', datetime.datetime(2001, 11, 27, 14, 9, 29)),
#  ('T/JO/112', 112.0, 'JO', 'C/JO/2674', 2.0, None, None, None, None, None, None, None, None, 0, None, None, 1, None, None, 0, None, None, 0, None, None, None, None, 0, 'deposition attested and request for commission to try and judge to be made.', None, None, None, None, 0.0, 0.0, 0, 0, None, None, 0, None, None, 0, None, 0, 0, 'No details of trial.', 0, None, None, None, None, None, None, None, None, None, None, None, None, None, 'jhm', datetime.datetime(2001, 6, 15, 10, 5, 39), 'jhm', datetime.datetime(2002, 10, 11, 16, 42, 26), 'CF/JO/40', 'JO', 40.0, 'T/JO/112', 0, 1, '25/7/1649', datetime.datetime(2049, 7, 25, 0, 0), None, 'Haddington', 0, 0, 0, None, 'jhm', datetime.datetime(2001, 6, 15, 10, 6, 51), 'jhm', datetime.datetime(2001, 6, 15, 10, 7, 33)),
#  ('T/JO/113', 113.0, 'JO', 'C/JO/2675', 2.0, None, None, None, None, None, None, None, None, 0, None, None, 1, None, None, 0, None, None, 0, None, None, None, None, 0, 'Deposition attested and request for commission to try and judge to be made.', None, None, None, None, 0.0, 0.0, 0, 0, None, None, 0, None, None, 0, None, 0, 0, 'No details', 0, None, None, None, None, None, None, None, None, None, None, None, None, None, 'jhm', datetime.datetime(2001, 6, 15, 10, 10, 37), 'jhm', datetime.datetime(2002, 10, 11, 16, 42, 31), 'CF/JO/41', 'JO', 41.0, 'T/JO/113', 0, 1, '25/7/1649', datetime.datetime(2049, 7, 25, 0, 0), None, 'Haddington', 0, 0, 0, None, 'jhm', datetime.datetime(2001, 6, 15, 10, 11, 42), 'jhm', datetime.datetime(2001, 6, 15, 10, 11, 51)),
#  ('T/JO/1132', 1132.0, 'JO', 'C/EGD/1935', 3.0, None, 'P/ST/1328', 'Paisley', 'Renfrew', None, None, None, None, 0, None, None, 0, None, None, 0, None, None, 0, None, None, None, None, 0, 'She was one of a number accused of bewitching Christian Shaw. Note in presbytery that the suspects were held in the houses of several of the minister ... (385 characters truncated) ... ings, even though they granted a commission.  For details of the proceedings of Privy Council in this matter see the no named witches case c/la/3235.', None, '13/4/1697', datetime.datetime(1997, 4, 13, 0, 0), None, None, None, 0, 0, 'Not Guilty', 'Released', 0, None, None, 0, None, 0, 0, 'Note in presbytery records on 17/3/1697 that ministers and commissioners to meet at Renfrew tomorrow.  The commission was read out in 18/3/1697.  But the trial happened on 13/4/1697 she was not proceeded against but was a star witness.', 0, None, None, None, None, None, None, None, None, None, None, None, None, None, 'jhm', datetime.datetime(2001, 12, 4, 14, 44, 8), 'jhm', datetime.datetime(2002, 10, 23, 10, 48, 44), 'CF/JO/453', 'JO', 453.0, 'T/JO/1132', 0, 1, '2/1697', datetime.datetime(1997, 2, 1, 0, 0), None, None, 0, 1, 0, None, 'jhm', datetime.datetime(2001, 12, 4, 15, 5, 34), 'LEM', datetime.datetime(2002, 1, 31, 10, 36, 24)),
#  ('T/JO/1133', 1133.0, 'JO', 'C/EGD/1780', 3.0, None, 'P/ST/1328', 'Paisley', 'Renfrew', None, None, None, None, 0, None, None, 0, None, None, 0, None, None, 0, None, None, None, None, 0, 'Note in presbytery that the suspects were held in the houses of the local ministers. One of several people accused by Christian Shaw.  Accused of try ... (447 characters truncated) ... ings, even though they granted a commission.  For details of the proceedings of Privy Council in this matter see the no named witches case c/la/3235.', None, '12/5/1697', datetime.datetime(1997, 5, 12, 0, 0), None, 16.0, 22.0, 1, 1, 'Guilty', 'Execution', 0, None, None, 0, None, 0, 0, 'Note in presbytery records on 18/3/1697 that the ministers and accused are to go to Renfrew tomorrow for the trial.  Trial started on 13/4/1697 but was continued until 12/5/1697 and lasted until 19/5/1697.', 1, 'Strangle & Burn', '10/6/1697', datetime.datetime(1997, 6, 10, 0, 0), 'Gallow Green', None, 'P/ST/1328', None, 'Renfrew', None, None, None, None, 'between 2-4', 'jhm', datetime.datetime(2001, 12, 4, 15, 0, 52), 'jhm', datetime.datetime(2002, 10, 28, 14, 58, 24), 'CF/JO/452', 'JO', 452.0, 'T/JO/1133', 0, 1, '2/1697', datetime.datetime(1997, 2, 1, 0, 0), None, None, 0, 0, 0, None, 'jhm', datetime.datetime(2001, 12, 4, 15, 4, 58), 'jhm', datetime.datetime(2001, 12, 4, 15, 5, 16)),
#  ('T/JO/1134', 1134.0, 'JO', 'C/JO/2934', 3.0, None, None, None, 'Renfrew', 'Renfrew', None, None, None, 0, None, None, 1, None, None, 0, None, None, 0, None, None, None, None, 0, "One of several people accused by Christian Shaw of bewitching her. Suspect held in the houses of the local ministers.  He was determined to be a witness not a suspect due to young age.  He was mentioned in the Privy Council commission but wasn't  tried with that group.", None, '13/4/1697', datetime.datetime(1997, 4, 13, 0, 0), None, None, 0.0, 0, 0, None, 'Released', 0, None, None, 0, None, 0, 0, 'Note in presbytery records on 17/3/1697 that the ministers and commissioners are to meet in Renfrew tomorrow for the trial.  Trials of other witches  ... (20 characters truncated) ...  but was continued until 12/5/1697 it lasted until the 19th.  He was never actually tried for witchcraft.  The charges were dropped due to young age.', 0, None, None, None, None, None, None, None, None, None, None, None, None, None, 'jhm', datetime.datetime(2001, 12, 4, 15, 8, 8), 'jhm', datetime.datetime(2002, 10, 18, 10, 51, 21), 'CF/JO/454', 'JO', 454.0, 'T/JO/1134', 0, 1, '2/1697', datetime.datetime(1997, 2, 1, 0, 0), None, None, 0, 1, 0, None, 'jhm', datetime.datetime(2001, 12, 4, 15, 9, 26), 'LEM', datetime.datetime(2002, 11, 1, 9, 53, 57)),
#  ('T/JO/1138', 1138.0, 'JO', 'C/JO/2936', 2.0, None, None, None, None, None, None, None, None, 0, None, None, 0, None, None, 0, None, None, 0, None, None, None, None, 0, 'Presbytery note that commission to be requested from Privy Council after she was referred to burgh council', None, None, None, None, 0.0, 0.0, 0, 0, None, None, 0, None, None, 0, None, 0, 0, None, 0, None, None, None, None, None, None, None, None, None, None, None, None, None, 'jhm', datetime.datetime(2001, 12, 5, 13, 41, 16), 'jhm', datetime.datetime(2001, 12, 5, 13, 42, 13), 'CF/JO/455', 'JO', 455.0, 'T/JO/1138', 0, 1, '11/1649', datetime.datetime(2049, 11, 1, 0, 0), None, None, 0, 0, 0, None, 'jhm', datetime.datetime(2001, 12, 5, 13, 42, 15), 'jhm', datetime.datetime(2001, 12, 5, 13, 42, 26)),
#  ('T/JO/114', 114.0, 'JO', 'C/JO/2676', 2.0, None, None, None, None, None, None, None, None, 0, None, None, 1, None, None, 0, None, None, 0, None, None, None, None, 0, 'deposition attested and commission for trial and judge to be requested.', None, None, None, None, 0.0, 0.0, 0, 0, None, None, 0, None, None, 0, None, 0, 0, 'No details.', 0, None, None, None, None, None, None, None, None, None, None, None, None, None, 'jhm', datetime.datetime(2001, 6, 15, 10, 14, 56), 'jhm', datetime.datetime(2002, 10, 11, 16, 42, 59), 'CF/JO/42', 'JO', 42.0, 'T/JO/114', 0, 1, '25/7/1649', datetime.datetime(2049, 7, 25, 0, 0), None, 'Haddington', 0, 0, 0, None, 'jhm', datetime.datetime(2001, 6, 15, 10, 15, 52), 'jhm', datetime.datetime(2001, 6, 15, 10, 16, 5)),
#  ('T/JO/1141', 1141.0, 'JO', 'C/JO/2939', 2.0, None, None, None, None, None, None, None, None, 0, None, None, 0, None, None, 0, None, None, 0, None, None, None, None, 0, "Presbytery note that the suspect was to be recommended to the 'judge ordinair' after she had confessed witchcraft.", None, None, None, None, 0.0, 0.0, 0, 0, None, None, 0, None, None, 0, None, 0, 0, None, 0, None, None, None, None, None, None, None, None, None, None, None, None, None, 'jhm', datetime.datetime(2001, 12, 5, 13, 58, 30), 'jhm', datetime.datetime(2001, 12, 5, 13, 59, 44), 'CF/JO/456', 'JO', 456.0, 'T/JO/1141', 0, 1, '7/1650', datetime.datetime(1950, 7, 1, 0, 0), None, None, 0, 0, 0, None, 'jhm', datetime.datetime(2001, 12, 5, 13, 59, 19), 'jhm', datetime.datetime(2001, 12, 5, 13, 59, 27)),
#  ('T/JO/1142', 1142.0, 'JO', 'C/JO/2940', 2.0, None, None, None, None, None, None, None, None, 0, None, None, 0, None, None, 0, None, None, 0, None, None, None, None, 0, "Presbytery note that the accused had confessed to witchcraft and they recommend referring her to the 'judge ordinair'.", None, None, None, None, 0.0, 0.0, 0, 0, None, None, 0, None, None, 0, None, 0, 0, None, 0, None, None, None, None, None, None, None, None, None, None, None, None, None, 'jhm', datetime.datetime(2001, 12, 5, 14, 3, 28), 'jhm', datetime.datetime(2001, 12, 5, 14, 4, 28), 'CF/JO/457', 'JO', 457.0, 'T/JO/1142', 0, 1, '7/1650', datetime.datetime(1950, 7, 1, 0, 0), None, None, 0, 0, 0, None, 'jhm', datetime.datetime(2001, 12, 5, 14, 4, 30), 'jhm', datetime.datetime(2001, 12, 5, 14, 5, 26)),
#  ('T/JO/115', 115.0, 'JO', 'C/JO/2677', 2.0, None, None, None, None, None, None, None, None, 0, None, None, 1, None, None, 0, None, None, 0, None, None, None, None, 0, 'deposition attested and commission to try and judge to be requested', None, None, None, None, 0.0, 0.0, 0, 0, None, None, 0, None, None, 0, None, 0, 0, 'No details.', 0, None, None, None, None, None, None, None, None, None, None, None, None, None, 'jhm', datetime.datetime(2001, 6, 15, 10, 21, 29), 'jhm', datetime.datetime(2002, 10, 11, 16, 43, 19), 'CF/JO/43', 'JO', 43.0, 'T/JO/115', 0, 1, '25/7/1649', datetime.datetime(2049, 7, 25, 0, 0), None, 'Haddington', 0, 0, 0, None, 'jhm', datetime.datetime(2001, 6, 15, 10, 22, 27), 'jhm', datetime.datetime(2001, 6, 15, 10, 22, 47)),
#  ('T/JO/116', 116.0, 'JO', 'C/JO/2678', 2.0, None, None, None, None, None, None, None, None, 0, None, None, 1, None, None, 0, None, None, 0, None, None, None, None, 0, 'Deposition attested and commission to try and judge to be requested.', None, None, None, None, 0.0, 0.0, 0, 0, None, None, 0, None, None, 0, None, 0, 0, 'No details.', 0, None, None, None, None, None, None, None, None, None, None, None, None, None, 'jhm', datetime.datetime(2001, 6, 15, 10, 27, 55), 'jhm', datetime.datetime(2002, 10, 11, 16, 43, 37), 'CF/JO/44', 'JO', 44.0, 'T/JO/116', 0, 1, '25/7/1649', datetime.datetime(2049, 7, 25, 0, 0), None, 'Haddington', 0, 0, 0, None, 'jhm', datetime.datetime(2001, 6, 15, 10, 28, 46), 'jhm', datetime.datetime(2001, 6, 15, 10, 28, 59)),
#  ('T/JO/117', 117.0, 'JO', 'C/JO/2679', 2.0, None, None, None, None, None, None, None, None, 0, None, None, 1, None, None, 0, None, None, 0, None, None, None, None, 0, 'Deposition attested and commission to try and judge to be requested.', None, None, None, None, 0.0, 0.0, 0, 0, None, None, 0, None, None, 0, None, 0, 0, 'No details.', 0, None, None, None, None, None, None, None, None, None, None, None, None, None, 'jhm', datetime.datetime(2001, 6, 15, 10, 31, 59), 'jhm', datetime.datetime(2002, 10, 11, 16, 43, 54), 'CF/JO/45', 'JO', 45.0, 'T/JO/117', 0, 1, '25/7/1649', datetime.datetime(2049, 7, 25, 0, 0), None, 'Haddington', 0, 0, 0, None, 'jhm', datetime.datetime(2001, 6, 15, 10, 32, 53), 'jhm', datetime.datetime(2001, 6, 15, 10, 33, 3)),
#  ('T/JO/1172', 1172.0, 'JO', 'C/EGD/2363', 2.0, None, None, None, None, None, None, None, None, 0, None, None, 0, None, None, 0, None, None, 0, None, None, None, None, 0, 'Recorded in presbytery records as having confessed to witchcraft but not to pact. Named others. Reported to have died of sickness.', None, None, None, None, 0.0, 0.0, 0, 0, None, None, 0, None, None, 0, None, 0, 0, None, 0, None, None, None, None, None, None, None, None, None, None, None, None, 'Reported to have died ?before trial.', 'jhm', datetime.datetime(2002, 1, 16, 11, 55, 4), 'jhm', datetime.datetime(2002, 10, 29, 8, 57, 14), 'CF/JO/550', 'JO', 550.0, 'T/JO/1172', 0, 1, '12/1648', datetime.datetime(2048, 12, 1, 0, 0), None, 'Balmerino', 0, 0, 0, None, 'jhm', datetime.datetime(2002, 8, 1, 12, 57, 30), 'jhm', datetime.datetime(2002, 8, 1, 12, 57, 52)),
#  ('T/JO/1177', 1177.0, 'JO', 'C/EGD/1866', 2.0, None, None, None, None, None, None, None, None, 0, None, None, 0, None, None, 0, None, None, 0, None, None, None, None, 1, 'Presbytery records note that accused was imprisoned and had confessed to witchcraft. The minister was to send the confessions to the judge in order t ... (46 characters truncated) ...  another entry in Aberdour kirk session records that the accused and 2 others named another woman and she was brought to the prison to confront them.', None, None, None, None, 0.0, 0.0, 0, 0, None, None, 0, None, None, 0, None, 0, 0, None, 0, None, None, None, None, None, None, None, None, None, None, None, None, None, 'jhm', datetime.datetime(2002, 1, 16, 15, 18, 12), 'jhm', datetime.datetime(2002, 10, 22, 15, 10, 27), 'CF/JO/460', 'JO', 460.0, 'T/JO/1177', 0, 1, '8/1661', datetime.datetime(1961, 8, 1, 0, 0), None, 'Aberdour', 0, 0, 0, None, 'jhm', datetime.datetime(2002, 1, 16, 15, 43, 19), 'jhm', datetime.datetime(2002, 1, 16, 15, 43, 28)),
#  ('T/JO/1178', 1178.0, 'JO', 'C/JO/2954', 2.0, None, None, None, None, None, None, None, None, 0, None, None, 1, None, None, 0, None, None, 0, None, None, None, None, 0, 'Presbytery records note that the accused was imprisoned and had confessed to witchcraft. The minister was to send confessions to the judge in order to proceed with a trial.', None, None, None, None, 0.0, 0.0, 0, 0, None, None, 0, None, None, 0, None, 0, 0, None, 0, None, None, None, None, None, None, None, None, None, None, None, None, None, 'jhm', datetime.datetime(2002, 1, 16, 15, 35, 36), 'jhm', datetime.datetime(2002, 10, 18, 10, 50, 46), 'CF/JO/458', 'JO', 458.0, 'T/JO/1178', 0, 1, '8/1661', datetime.datetime(1961, 8, 1, 0, 0), None, 'Aberdour', 0, 0, 0, None, 'jhm', datetime.datetime(2002, 1, 16, 15, 36, 29), 'jhm', datetime.datetime(2002, 1, 16, 15, 36, 39)),
#  ('T/JO/1179', 1179.0, 'JO', 'C/JO/2955', 2.0, None, None, None, None, None, None, None, None, 0, None, None, 1, None, None, 0, None, None, 0, None, None, None, None, 1, 'Presbytery records note that the accused was imprisoned and had confessed to witchcraft. The minister was to send confessions to the judge in order t ... (20 characters truncated) ... al. Another entry in Aberdour kirk session notes that the accused and 2 other women accused a third woman who was brought to confront them in prison.', None, None, None, None, 0.0, 0.0, 0, 0, None, None, 0, None, None, 0, None, 0, 0, None, 0, None, None, None, None, None, None, None, None, None, None, None, None, None, 'jhm', datetime.datetime(2002, 1, 16, 15, 40, 40), 'jhm', datetime.datetime(2002, 10, 18, 10, 50, 18), 'CF/JO/459', 'JO', 459.0, 'T/JO/1179', 0, 1, '8/1661', datetime.datetime(1961, 8, 1, 0, 0), None, 'Aberdour', 0, 0, 0, None, 'jhm', datetime.datetime(2002, 1, 16, 15, 41, 48), 'jhm', datetime.datetime(2002, 1, 16, 15, 42, 9)),
#  ('T/JO/118', 118.0, 'JO', 'C/JO/2680', 2.0, None, None, None, None, None, None, None, None, 0, None, None, 1, None, None, 0, None, None, 0, None, None, None, None, 0, 'Deposition attested and commission to try and judge to be requested.', None, None, None, None, 0.0, 0.0, 0, 0, None, None, 0, None, None, 0, None, 0, 0, 'No details', 0, None, None, None, None, None, None, None, None, None, None, None, None, None, 'jhm', datetime.datetime(2001, 6, 15, 10, 36, 6), 'jhm', datetime.datetime(2002, 10, 11, 16, 44, 2), 'CF/JO/46', 'JO', 46.0, 'T/JO/118', 0, 1, '25/7/1649', datetime.datetime(2049, 7, 25, 0, 0), None, 'Haddington', 0, 0, 0, None, 'jhm', datetime.datetime(2001, 6, 15, 10, 37, 1), 'jhm', datetime.datetime(2001, 6, 15, 10, 37, 10)),
#  ('T/JO/120', 120.0, 'JO', 'C/JO/2681', 2.0, None, None, None, None, None, None, None, None, 0, None, None, 0, None, None, 0, None, None, 0, None, None, None, None, 0, 'deposition attested sufficient grounds to request commission to try and judge.', None, None, None, None, 0.0, 0.0, 0, 0, None, None, 0, None, None, 0, None, 0, 0, 'No details.', 0, None, None, None, None, None, None, None, None, None, None, None, None, None, 'jhm', datetime.datetime(2001, 6, 15, 11, 53, 23), 'jhm', datetime.datetime(2001, 6, 15, 11, 54, 35), 'CF/JO/47', 'JO', 47.0, 'T/JO/120', 0, 1, '8/8/1649', datetime.datetime(2049, 8, 8, 0, 0), None, 'Haddington', 0, 0, 0, None, 'jhm', datetime.datetime(2001, 6, 15, 11, 54, 14), 'jhm', datetime.datetime(2001, 6, 15, 11, 54, 27)),
#  ('T/JO/1206', 1206.0, 'JO', 'C/EGD/2387', 2.0, None, None, None, None, None, None, None, None, 0, None, None, 0, None, None, 0, None, None, 0, None, None, None, None, 0, 'Witnessed questioned by presbytery. Accused imprisoned and confessed to demonic pact. Named others.\r\n?no more details or information about what happened.', None, None, None, None, 8.0, 3.0, 0, 0, None, None, 0, None, None, 0, None, 0, 0, None, 0, None, None, None, None, None, None, None, None, None, None, None, None, None, 'jhm', datetime.datetime(2002, 2, 7, 10, 25, 30), 'jhm', datetime.datetime(2002, 10, 29, 10, 5, 55), 'CF/JO/464', 'JO', 464.0, 'T/JO/1206', 0, 1, '29/12/1649', datetime.datetime(2049, 12, 29, 0, 0), None, 'Brechin', 0, 1, 0, None, 'jhm', datetime.datetime(2002, 2, 7, 10, 25, 54), 'jhm', datetime.datetime(2002, 2, 7, 10, 26, 21)),
#  ('T/JO/1207', 1207.0, 'JO', 'C/EGD/1856', 2.0, None, None, None, None, None, None, None, None, 0, None, None, 0, None, None, 0, None, None, 0, None, None, None, None, 0, 'Presbytery questioned accused and witnesses. Appears to have died after her confession. Recorded that she named others but no names.', None, None, None, None, 2.0, 2.0, 0, 0, None, None, 0, None, None, 0, None, 0, 0, 'She appeared to have died after her confession so likely no trial held.', 0, None, None, None, None, None, None, None, None, None, None, None, None, None, 'jhm', datetime.datetime(2002, 2, 7, 11, 22, 44), 'jhm', datetime.datetime(2002, 11, 11, 13, 0, 44), 'CF/JO/465', 'JO', 465.0, 'T/JO/1207', 0, 1, None, None, None, 'Brechin', 0, 1, 0, None, 'jhm', datetime.datetime(2002, 2, 7, 11, 22, 57), 'jhm', datetime.datetime(2002, 2, 7, 11, 23, 9)),
#  ('T/JO/1208', 1208.0, 'JO', 'C/EGD/1855', 2.0, None, None, None, None, None, None, None, None, 0, None, None, 0, None, None, 0, None, None, 0, None, None, None, None, 0, 'Witnesses and accused questioned by the presbytery. Noted that she had been imprisoned. Minutes are confusing as presbytery implied that she had not confessed but brought 16 male witnesses who had guarded her and to whom she appeared to have confessed some items.', None, None, None, None, 3.0, 22.0, 0, 0, None, None, 0, None, None, 0, None, 0, 0, None, 0, None, None, None, None, None, None, None, None, None, None, None, None, None, 'jhm', datetime.datetime(2002, 2, 7, 14, 15, 28), 'jhm', datetime.datetime(2002, 11, 11, 13, 1, 13), 'CF/JO/466', 'JO', 466.0, 'T/JO/1208', 0, 1, '4/1650', datetime.datetime(1950, 4, 1, 0, 0), None, 'Brechin', 0, 1, 0, None, 'jhm', datetime.datetime(2002, 2, 7, 14, 16, 22), 'jhm', datetime.datetime(2002, 2, 14, 10, 47, 28)),
# ...
#  ('T/LA/854', 854.0, 'LA', 'C/EGD/705', 3.0, None, None, None, None, None, None, None, None, 0, None, None, 0, None, None, 0, None, None, 0, None, None, None, None, 0, 'The procedure was going ahead locally, but the High Court and the commissions sent people out to investigate allegations of torture.  The central representatives found evidence of torture (of several kinds), ordered all the suspects released, and cautioned for if new charges were brought.', None, None, None, None, 0.0, 0.0, 0, 0, None, None, 0, None, None, 0, None, 0, 0, None, 0, None, None, None, None, None, None, None, None, None, None, None, None, None, 'LEM', datetime.datetime(2001, 9, 21, 15, 49, 17), 'LEM', datetime.datetime(2002, 11, 6, 14, 43, 15), 'CF/LA/514', 'LA', 514.0, 'T/LA/854', 0, 1, '27/11/1679', datetime.datetime(1979, 11, 27, 0, 0), 'Tolbooth', "Bo'ness", 0, 1, 0, None, 'LEM', datetime.datetime(2002, 7, 4, 16, 11, 38), 'LEM', datetime.datetime(2002, 7, 4, 16, 11, 58)),
#  ('T/LA/854', 854.0, 'LA', 'C/EGD/705', 3.0, None, None, None, None, None, None, None, None, 0, None, None, 0, None, None, 0, None, None, 0, None, None, None, None, 0, 'The procedure was going ahead locally, but the High Court and the commissions sent people out to investigate allegations of torture.  The central representatives found evidence of torture (of several kinds), ordered all the suspects released, and cautioned for if new charges were brought.', None, None, None, None, 0.0, 0.0, 0, 0, None, None, 0, None, None, 0, None, 0, 0, None, 0, None, None, None, None, None, None, None, None, None, None, None, None, None, 'LEM', datetime.datetime(2001, 9, 21, 15, 49, 17), 'LEM', datetime.datetime(2002, 11, 6, 14, 43, 15), 'CF/LA/335', 'LA', 335.0, 'T/LA/854', 0, 1, None, None, None, None, 0, 0, 1, None, 'LEM', datetime.datetime(2001, 9, 21, 15, 49, 26), 'LEM', datetime.datetime(2001, 9, 21, 15, 49, 48)),
#  ('T/LA/869', 869.0, 'LA', 'C/EGD/34', 1.0, 'Edinburgh', None, None, None, None, None, None, None, 0, None, None, 0, None, None, 0, None, None, 0, None, None, None, None, 0, None, None, '28/5/1588', datetime.datetime(1988, 5, 28, 0, 0), None, 0.0, 0.0, 0, 0, None, None, 0, None, None, 0, None, 0, 0, None, 0, None, None, None, None, None, None, None, None, None, None, None, None, None, 'LEM', datetime.datetime(2001, 9, 25, 11, 57, 17), 'jhm', datetime.datetime(2003, 12, 23, 12, 53, 46), 'CF/LA/352', 'LA', 352.0, 'T/LA/869', 1, 1, None, None, None, 'Edinburgh', 0, 1, 0, None, 'LEM', datetime.datetime(2001, 9, 25, 11, 57, 21), 'LEM', datetime.datetime(2001, 9, 25, 11, 57, 35)),
#  ('T/LA/870', 870.0, 'LA', 'C/EGD/127', 2.0, None, None, None, None, None, None, None, None, 0, None, None, 0, None, None, 0, None, None, 0, None, None, None, None, 0, 'Her husband and children were tortured in front of her.', None, None, None, None, 0.0, 0.0, 0, 0, 'Guilty', 'Execution', 0, None, None, 0, None, 0, 0, None, 1, 'Burn', '15/12/1594', datetime.datetime(1994, 12, 15, 0, 0), 'Hedding-hill', None, None, None, 'Orkney', 'Kirkwall', None, None, None, None, 'LEM', datetime.datetime(2001, 9, 25, 14, 48, 10), 'LEM', datetime.datetime(2001, 10, 3, 12, 48, 13), 'CF/LA/360', 'LA', 360.0, 'T/LA/870', 1, 1, '16/12/1594', datetime.datetime(1994, 12, 16, 0, 0), None, 'Orkney', 0, 0, 0, None, 'LEM', datetime.datetime(2001, 10, 3, 12, 45, 29), 'LEM', datetime.datetime(2001, 10, 3, 12, 46)),
#  ('T/LA/870', 870.0, 'LA', 'C/EGD/127', 2.0, None, None, None, None, None, None, None, None, 0, None, None, 0, None, None, 0, None, None, 0, None, None, None, None, 0, 'Her husband and children were tortured in front of her.', None, None, None, None, 0.0, 0.0, 0, 0, 'Guilty', 'Execution', 0, None, None, 0, None, 0, 0, None, 1, 'Burn', '15/12/1594', datetime.datetime(1994, 12, 15, 0, 0), 'Hedding-hill', None, None, None, 'Orkney', 'Kirkwall', None, None, None, None, 'LEM', datetime.datetime(2001, 9, 25, 14, 48, 10), 'LEM', datetime.datetime(2001, 10, 3, 12, 48, 13), 'CF/LA/353', 'LA', 353.0, 'T/LA/870', 0, 1, '12/1594', datetime.datetime(1994, 12, 1, 0, 0), None, 'Orkney', 0, 1, 1, None, 'LEM', datetime.datetime(2001, 9, 25, 14, 48, 23), 'jhm', datetime.datetime(2002, 10, 3, 11, 36, 47)),
#  ('T/LA/873', 873.0, 'LA', 'C/EGD/129', 1.0, 'Edinburgh', None, None, None, None, None, None, None, 0, None, None, 1, None, None, 0, None, None, 0, None, None, None, None, 0, 'She confessed twice in the Lodgings of Lord Gowrie in Perth. And again in Edinburgh in front of prominent ministers.  She also confessed at Linlithgow in the presence of Sir George Hume, and King James VI.', None, '27/11/1596', datetime.datetime(1996, 11, 27, 0, 0), None, 0.0, 0.0, 0, 0, 'Guilty', 'Execution', 0, None, None, 0, None, 0, 0, 'Trial was ordered under the signet.', 1, 'Burn', None, None, None, None, None, None, None, None, None, None, None, None, 'LEM', datetime.datetime(2001, 9, 25, 15, 36, 43), 'LEM', datetime.datetime(2003, 10, 29, 10, 47, 55), 'CF/LA/359', 'LA', 359.0, 'T/LA/873', 1, 1, '9/1596', datetime.datetime(1996, 9, 1, 0, 0), None, 'Linlithgow', 0, 0, 0, None, 'LEM', datetime.datetime(2001, 10, 3, 12, 8, 47), 'LEM', datetime.datetime(2001, 10, 3, 12, 8, 55)),
#  ('T/LA/873', 873.0, 'LA', 'C/EGD/129', 1.0, 'Edinburgh', None, None, None, None, None, None, None, 0, None, None, 1, None, None, 0, None, None, 0, None, None, None, None, 0, 'She confessed twice in the Lodgings of Lord Gowrie in Perth. And again in Edinburgh in front of prominent ministers.  She also confessed at Linlithgow in the presence of Sir George Hume, and King James VI.', None, '27/11/1596', datetime.datetime(1996, 11, 27, 0, 0), None, 0.0, 0.0, 0, 0, 'Guilty', 'Execution', 0, None, None, 0, None, 0, 0, 'Trial was ordered under the signet.', 1, 'Burn', None, None, None, None, None, None, None, None, None, None, None, None, 'LEM', datetime.datetime(2001, 9, 25, 15, 36, 43), 'LEM', datetime.datetime(2003, 10, 29, 10, 47, 55), 'CF/LA/358', 'LA', 358.0, 'T/LA/873', 0, 1, '19/8/1596', datetime.datetime(1996, 8, 19, 0, 0), 'House', 'Perth', 0, 0, 0, None, 'LEM', datetime.datetime(2001, 10, 3, 12, 0, 18), 'LEM', datetime.datetime(2001, 10, 3, 12, 0, 28)),
#  ('T/LA/873', 873.0, 'LA', 'C/EGD/129', 1.0, 'Edinburgh', None, None, None, None, None, None, None, 0, None, None, 1, None, None, 0, None, None, 0, None, None, None, None, 0, 'She confessed twice in the Lodgings of Lord Gowrie in Perth. And again in Edinburgh in front of prominent ministers.  She also confessed at Linlithgow in the presence of Sir George Hume, and King James VI.', None, '27/11/1596', datetime.datetime(1996, 11, 27, 0, 0), None, 0.0, 0.0, 0, 0, 'Guilty', 'Execution', 0, None, None, 0, None, 0, 0, 'Trial was ordered under the signet.', 1, 'Burn', None, None, None, None, None, None, None, None, None, None, None, None, 'LEM', datetime.datetime(2001, 9, 25, 15, 36, 43), 'LEM', datetime.datetime(2003, 10, 29, 10, 47, 55), 'CF/LA/357', 'LA', 357.0, 'T/LA/873', 0, 1, '28/8/1596', datetime.datetime(1996, 8, 28, 0, 0), 'House', 'Perth', 0, 0, 0, None, 'LEM', datetime.datetime(2001, 10, 3, 11, 59, 20), 'LEM', datetime.datetime(2001, 10, 3, 12, 0, 6)),
#  ('T/LA/873', 873.0, 'LA', 'C/EGD/129', 1.0, 'Edinburgh', None, None, None, None, None, None, None, 0, None, None, 1, None, None, 0, None, None, 0, None, None, None, None, 0, 'She confessed twice in the Lodgings of Lord Gowrie in Perth. And again in Edinburgh in front of prominent ministers.  She also confessed at Linlithgow in the presence of Sir George Hume, and King James VI.', None, '27/11/1596', datetime.datetime(1996, 11, 27, 0, 0), None, 0.0, 0.0, 0, 0, 'Guilty', 'Execution', 0, None, None, 0, None, 0, 0, 'Trial was ordered under the signet.', 1, 'Burn', None, None, None, None, None, None, None, None, None, None, None, None, 'LEM', datetime.datetime(2001, 9, 25, 15, 36, 43), 'LEM', datetime.datetime(2003, 10, 29, 10, 47, 55), 'CF/LA/354', 'LA', 354.0, 'T/LA/873', 1, 1, '23/9/1596', datetime.datetime(1996, 9, 23, 0, 0), None, 'Edinburgh', 0, 0, 0, None, 'LEM', datetime.datetime(2001, 9, 25, 15, 39, 36), 'LEM', datetime.datetime(2001, 10, 3, 12, 5, 48)),
#  ('T/LA/88', 88.0, 'LA', 'C/EGD/167', 1.0, 'Edinburgh', None, None, None, None, None, None, None, 1, None, None, 1, '5/11/1629', datetime.datetime(2029, 11, 5, 0, 0), 0, None, None, 0, None, None, None, None, 0, 'He was watched and warded until he confessed, then moved to Edinburgh.  Investigated by the presbytery of Dalkeith. Presbytery note 15/10/1629 that he was to be arrested according to warrant from council. Request help with this.', None, '2/4/1630', datetime.datetime(2030, 4, 2, 0, 0), None, 0.0, 9.0, 0, 0, 'Guilty', 'Execution', 0, None, None, 0, None, 0, 0, None, 1, 'Strangle & Burn', None, None, None, None, None, None, None, None, None, None, None, 'Executed at Newbattle', 'LEM', datetime.datetime(2001, 6, 13, 12, 5, 28), 'LEM', datetime.datetime(2003, 3, 3, 12, 32, 41), 'CF/LA/25', 'LA', 25.0, 'T/LA/88', 0, 1, '5/11/1629', datetime.datetime(2029, 11, 5, 0, 0), 'House', 'Newbattle Kirk', 0, 0, 0, None, 'LEM', datetime.datetime(2001, 6, 13, 12, 13, 51), 'jhm', datetime.datetime(2002, 10, 21, 15, 47, 24)),
#  ('T/LA/895', 895.0, 'LA', 'C/EGD/45', 2.0, None, None, None, 'Ross', None, None, None, None, 0, None, None, 0, None, None, 0, None, None, 0, None, None, None, None, 0, None, None, '28/11/1577', datetime.datetime(1977, 11, 28, 0, 0), 'Cathedral', 0.0, 0.0, 0, 0, 'Guilty', 'Execution', 0, None, None, 0, None, 0, 0, 'Under commission from the king.  Held in the cathedral kirk of Ross.', 1, 'Burn', None, None, None, None, None, None, None, None, None, None, None, None, 'LEM', datetime.datetime(2001, 10, 8, 11, 52, 1), 'jhm', datetime.datetime(2002, 11, 7, 10, 28, 29), 'CF/LA/361', 'LA', 361.0, 'T/LA/895', 0, 1, None, None, None, None, 0, 1, 0, None, 'LEM', datetime.datetime(2001, 10, 8, 11, 55, 28), 'LEM', datetime.datetime(2001, 10, 8, 11, 58, 44)),
#  ('T/LA/908', 908.0, 'LA', 'C/EGD/56', 1.0, 'Edinburgh', None, None, None, None, None, None, None, 0, None, None, 0, None, None, 1, None, None, 0, None, None, None, None, 0, 'summons against her on 23/7/1590, she was fugitive and her husband was ordered to bring her to trial.', None, '17/8/1590', datetime.datetime(1990, 8, 17, 0, 0), None, 0.0, 0.0, 0, 0, 'Guilty', 'Execution', 0, None, None, 0, None, 0, 0, 'listed on a High Court index for 22/7/1590', 1, 'Strangle & Burn', None, None, 'Castle Hill', None, None, None, None, None, None, None, None, None, 'LEM', datetime.datetime(2001, 10, 8, 14, 27, 41), 'LEM', datetime.datetime(2002, 11, 7, 15, 24, 34), 'CF/LA/618', 'LA', 618.0, 'T/LA/908', 0, 1, None, None, None, 'Inch', 0, 0, 0, None, 'LEM', datetime.datetime(2002, 8, 28, 13, 23, 10), 'LEM', datetime.datetime(2002, 8, 28, 13, 23, 46)),
#  ('T/LA/908', 908.0, 'LA', 'C/EGD/56', 1.0, 'Edinburgh', None, None, None, None, None, None, None, 0, None, None, 0, None, None, 1, None, None, 0, None, None, None, None, 0, 'summons against her on 23/7/1590, she was fugitive and her husband was ordered to bring her to trial.', None, '17/8/1590', datetime.datetime(1990, 8, 17, 0, 0), None, 0.0, 0.0, 0, 0, 'Guilty', 'Execution', 0, None, None, 0, None, 0, 0, 'listed on a High Court index for 22/7/1590', 1, 'Strangle & Burn', None, None, 'Castle Hill', None, None, None, None, None, None, None, None, None, 'LEM', datetime.datetime(2001, 10, 8, 14, 27, 41), 'LEM', datetime.datetime(2002, 11, 7, 15, 24, 34), 'CF/LA/362', 'LA', 362.0, 'T/LA/908', 0, 1, None, None, None, 'Edinburgh', 0, 0, 0, None, 'LEM', datetime.datetime(2001, 10, 8, 15, 0, 10), 'LEM', datetime.datetime(2001, 10, 8, 15, 0, 18)),
#  ('T/LA/909', 909.0, 'LA', 'C/EGD/53', 1.0, 'Edinburgh', None, None, None, None, None, None, None, 0, None, None, 0, None, None, 1, None, None, 0, None, None, None, None, 0, 'Summons against her on 23/7/1590. She was fugitive and her husband was ordered to get her to report for trial. She appeared later for her trial.', None, '17/8/1590', datetime.datetime(1990, 8, 17, 0, 0), None, 0.0, 0.0, 0, 0, 'Guilty', 'Execution', 0, None, None, 0, None, 0, 0, None, 1, 'Strangle & Burn', None, None, 'Castle Hill', None, None, None, None, None, None, None, None, None, 'LEM', datetime.datetime(2001, 10, 8, 14, 35, 10), 'jhm', datetime.datetime(2002, 11, 7, 16, 15, 46), 'CF/LA/363', 'LA', 363.0, 'T/LA/909', 0, 1, None, None, None, 'Edinburgh', 0, 0, 0, None, 'LEM', datetime.datetime(2001, 10, 8, 15, 1, 19), 'LEM', datetime.datetime(2001, 10, 8, 15, 1, 21)),
#  ('T/LA/928', 928.0, 'LA', 'C/EGD/59', 1.0, 'Edinburgh', None, None, None, None, None, None, None, 0, None, None, 0, None, None, 0, None, None, 0, None, None, None, None, 0, 'Newes From Scotland describes extreme toture being used against him - notably the bootes.', None, '26/12/1590', datetime.datetime(1990, 12, 26, 0, 0), None, 0.0, 0.0, 0, 0, 'Guilty', None, 0, None, None, 0, None, 0, 0, None, 0, None, None, None, None, None, None, None, None, None, None, None, None, None, 'LEM', datetime.datetime(2001, 10, 9, 9, 18, 35), 'jhm', datetime.datetime(2002, 11, 12, 9, 10, 40), 'CF/LA/392', 'LA', 392.0, 'T/LA/928', 0, 1, None, None, None, 'Edinburgh', 0, 0, 0, None, 'LEM', datetime.datetime(2001, 10, 9, 9, 30, 52), 'LEM', datetime.datetime(2001, 10, 9, 9, 30, 53)),
#  ('T/LA/934', 934.0, 'LA', 'C/EGD/63', 1.0, 'Edinburgh', None, None, None, None, None, None, None, 0, None, None, 0, None, None, 0, None, None, 0, None, None, None, None, 1, "Mega-confession where she denied the demonic elements and confessed to folk healing.  She denied all the North Berwick stuff, but eventually confesse ... (124 characters truncated) ... as confronted with other suspects on the 15 January but can't read the year, probably 1591.  She was confronted with Gellie Duncan and Jonat Campbel.", None, '21/1/1591', datetime.datetime(1991, 1, 21, 0, 0), None, 0.0, 0.0, 1, 0, 'Guilty', 'Execution', 0, None, None, 0, None, 0, 0, "described as convicted by an assize and 'brint' 28/1/1591 in calendar of State papers.", 1, 'Strangle & Burn', '28/1/1591', datetime.datetime(1991, 1, 28, 0, 0), 'Castle Hill', None, None, None, None, None, None, None, None, 'The date was given in Calendar of State Papers.', 'LEM', datetime.datetime(2001, 10, 9, 10, 21, 47), 'jhm', datetime.datetime(2003, 12, 23, 12, 59, 26), 'CF/LA/550', 'LA', 550.0, 'T/LA/934', 0, 1, None, None, None, None, 1, 0, 0, None, 'LEM', datetime.datetime(2002, 7, 26, 10, 48, 42), 'LEM', datetime.datetime(2002, 7, 26, 10, 48, 50)),
#  ('T/LA/934', 934.0, 'LA', 'C/EGD/63', 1.0, 'Edinburgh', None, None, None, None, None, None, None, 0, None, None, 0, None, None, 0, None, None, 0, None, None, None, None, 1, "Mega-confession where she denied the demonic elements and confessed to folk healing.  She denied all the North Berwick stuff, but eventually confesse ... (124 characters truncated) ... as confronted with other suspects on the 15 January but can't read the year, probably 1591.  She was confronted with Gellie Duncan and Jonat Campbel.", None, '21/1/1591', datetime.datetime(1991, 1, 21, 0, 0), None, 0.0, 0.0, 1, 0, 'Guilty', 'Execution', 0, None, None, 0, None, 0, 0, "described as convicted by an assize and 'brint' 28/1/1591 in calendar of State papers.", 1, 'Strangle & Burn', '28/1/1591', datetime.datetime(1991, 1, 28, 0, 0), 'Castle Hill', None, None, None, None, None, None, None, None, 'The date was given in Calendar of State Papers.', 'LEM', datetime.datetime(2001, 10, 9, 10, 21, 47), 'jhm', datetime.datetime(2003, 12, 23, 12, 59, 26), 'CF/LA/447', 'LA', 447.0, 'T/LA/934', 1, 1, '27/1/1591', datetime.datetime(1991, 1, 27, 0, 0), None, 'Edinburgh', 1, 0, 0, None, 'LEM', datetime.datetime(2001, 11, 21, 14, 17, 54), 'LEM', datetime.datetime(2001, 11, 21, 14, 19, 18))]

# %%
# %%sql
# SELECT
#     COUNT(DISTINCT trial.trialref) AS Number_of_Trials,
#     COUNT(DISTINCT confession.trialref) AS Number_of_Confessions,
#     (COUNT(DISTINCT confession.trialref)/COUNT(DISTINCT trial.trialref)) AS Share_of_Confessions
# FROM trial
# LEFT JOIN confession
# ON trial.trialref = confession.trialref
# Out:
#  * mysql+pymysql://student:***@witchcraft.csbmzoea3lu9.us-east-1.rds.amazonaws.com/witchcraft
# 1 rows affected.
# [(3211, 756, Decimal('0.2354'))]

# %% [markdown]
# ##### b) Only a small number of trials have records of torture. Is there a higher share of confessions among trials with records of torture than trials without such record? Hint: You will need to merge on the confession table.

# %%
# %%sql
# WITH trial_tortured AS(
# SELECT COUNT(DISTINCT trialref) as num_of_toutured_trial
# FROM torture)
#
# SELECT (COUNT(DISTINCT torture.trialref) / (SELECT num_of_toutured_trial FROM trial_tortured)) as share_of_confession_tortured
# FROM torture
# LEFT JOIN confession
# ON torture.trialref = confession.trialref
# WHERE confessionref IS NOT NULL
# Out:
#  * mysql+pymysql://student:***@witchcraft.csbmzoea3lu9.us-east-1.rds.amazonaws.com/witchcraft
# 1 rows affected.
# [(Decimal('0.4231'),)]

# %%
# %%sql
# WITH trial_not_torture AS(
# SELECT *
# FROM trial
# WHERE trialref NOT IN (SELECT DISTINCT trialref FROM torture))
#
# SELECT COUNT(DISTINCT trial_not_torture.trialref) / (SELECT COUNT(trial_not_torture.trialref) FROM trial_not_torture) AS share_of_confession_notortured
# FROM trial_not_torture
# LEFT JOIN confession
# ON trial_not_torture.trialref = confession.trialref
# WHERE confessionref IS NOT NULL
# Out:
#  * mysql+pymysql://student:***@witchcraft.csbmzoea3lu9.us-east-1.rds.amazonaws.com/witchcraft
# 1 rows affected.
# [(Decimal('0.2324'),)]
